# %% [markdown]
# # 重新整理数据 `download` -> `raw72`

# %%
from cosmic.utils import merge_fits_by_ra

result = merge_fits_by_ra(
    input_dir="/disk_b/tiandc/DR9x10_Gaia/download",
    output_dir="/disk_b/tiandc/DR9x10_Gaia/raw72",
    output_filename="lsdr9x10_{i:02d}.fits",
    temp_dir="./temp",
    num_processes=60,
    ra_column='ra',
    fits_extension="*.fits",
    data_hdu_index=1,
    buffer_flush_size=2000000,
    bin_size=5.0,
    add_uid=True
)
# Out:
# Step 1: Setting up directories...
#
# Step 2: Preparing file list for 60 parallel processes...
# Found 923 source files.
# Total data size: 209.82 GB
#
# Step 3: Starting parallel processing...
# Parallel processing finished in 9.23 minutes.
#
# Step 4: Consolidating temporary files into final output files...
# Consolidating bins: 100%|██████████| 72/72 [2:06:03<00:00, 105.05s/it]
# Step 5: Cleaning up temporary directory...
#
# --- All Done! ---
# Processing complete in 135.55 minutes.
# Total rows processed: 880,526,263
# Final files are located in: /disk_b/tiandc/DR9x10_Gaia/raw72
